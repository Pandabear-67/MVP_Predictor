# %% [markdown]
# **Extracting MVP Votes from 1990-1991 to 2022-2023 season**

# %%
import requests
import os
import shutil
import time

# %%
years = list(range(1991,2024))

# %%
url_start = "https://www.basketball-reference.com/awards/awards_{}.html"

for year in years:
    url = url_start.format(year)
    
    data = requests.get(url)
    time.sleep(15)
    
    with open("mvp_votes/{}.html".format(year), "w+") as f:
        f.write(data.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d45eef28dd7a> in <module>
#       7     time.sleep(15)
#       8
# ----> 9     with open("mvp_votes/{}.html".format(year), "w+") as f:
#      10         f.write(data.text)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mvp_votes/1991.html'

# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
dfs = []
for year in years:
    with open("mvp_votes/{}.html".format(year)) as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_="over_header").decompose()
    mvp_table = soup.find_all(id="mvp")[0]
    mvp_df = pd.read_html(str(mvp_table))[0]
    mvp_df["Year"] = year
    dfs.append(mvp_df)

# %%
mvps = pd.concat(dfs)

# %%
mvps.to_csv("mvps.csv")

# %% [markdown]
# **Player stats per game from 1990-91 to 2022-2023 season.**

# %%
player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

for year in years:
    url = player_stats_url.format(year)
    
    data = requests.get(url)
    time.sleep(15)
    
    with open("player_stats/{}.html".format(year), "w+") as f:
        f.write(data.text)

# %%
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time

# install selenium chrome driver from https://chromedriver.chromium.org/downloads
# xattr -d com.apple.quarantine chromedriver

# %%
driver = webdriver.Chrome(
    service=Service(executable_path="C:/Users/vuyyu/Dropbox/PC/Desktop/Program_Installers/chromedriver-win64/chromedriver-win64/chromedriver.exe")
    )

# %%
for year in years:
    url = player_stats_url.format(year)
    
    driver.get(url)
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(2)
    
    with open("player_stats/{}.html".format(year), "w+") as f:
        f.write(driver.page_source)

# %%
dfs = []
for year in years:
    with open("player_stats/{}.html".format(year)) as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    player_table = soup.find_all(id="per_game_stats")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
players = pd.concat(dfs)
players.head()
# Out:
#   Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...  ORB  DRB  \
# 0  1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  ...  0.6  1.4
# 1  2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  ...  0.5  1.3
# 2  3          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  ...  2.1  3.2
# 3  4       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  ...  0.9  3.0
# 4  5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  ...  1.7  3.1
#
#    TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 31 columns]

# %%
players.to_csv("players_stats.csv")

# %% [markdown]
# **Getting Advanced stats from 1990-91 to 2022-2023 season.**

# %%
advanced_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_advanced.html"

for year in years:
    url = advanced_stats_url.format(year)
    
    data = requests.get(url)
    time.sleep(15)
    
    with open("advanced_stats/{}.html".format(year), "w+") as f:
        f.write(data.text)

# %%
for year in years:
    url = advanced_stats_url.format(year)
    
    driver.get(url)
    driver.execute_script("window.scrollTo(1,10000)")
    time.sleep(2)
    
    with open("advanced_stats/{}.html".format(year), "w+") as f:
        f.write(driver.page_source)

# %%
dfs = []
for year in years:
    with open("advanced_stats/{}.html".format(year)) as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    player_table = soup.find_all(id="advanced_stats")[0]
    player_df = pd.read_html(str(player_table))[0]
    player_df["Year"] = year
    dfs.append(player_df)

# %%
players_advanced = pd.concat(dfs)
players_advanced.head()
# Out:
#   Rk              Player Pos Age   Tm   G    MP   PER   TS%  3PAr  ...   OWS  \
# 0  1      Alaa Abdelnaby  PF  22  POR  43   290  13.1  .499  .000  ...   0.0
# 1  2  Mahmoud Abdul-Rauf  PG  21  DEN  67  1505  12.2  .448  .099  ...  -0.7
# 2  3          Mark Acres   C  28  ORL  68  1313   9.2  .551  .014  ...   1.4
# 3  4       Michael Adams  PG  28  DEN  66  2346  22.3  .530  .397  ...   5.8
# 4  5        Mark Aguirre  SF  31  DET  78  2006  16.7  .526  .086  ...   2.8
#
#     DWS    WS   WS/48 Unnamed: 24  OBPM  DBPM   BPM  VORP  Year
# 0   0.5   0.5    .079         NaN  -3.4  -1.2  -4.6  -0.2  1991
# 1  -0.3  -1.0  -0.031         NaN  -2.0  -3.0  -5.0  -1.1  1991
# 2   1.1   2.5    .090         NaN  -2.8  -0.2  -3.0  -0.3  1991
# 3   0.4   6.3    .128         NaN   6.0  -0.7   5.3   4.3  1991
# 4   2.7   5.5    .132         NaN   1.2   0.2   1.4   1.7  1991
#
# [5 rows x 30 columns]

# %%
del players_advanced["Unnamed: 19"]
del players_advanced["Unnamed: 24"]

# %%
players_advanced.to_csv("players_advanced_stats.csv")

# %% [markdown]
# **Getting team standings from 1990-91 to 2022-23 season.**

# %%
team_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html"

# %%
for year in years:
    url = team_stats_url.format(year)
    
    data = requests.get(url)
    time.sleep(15)
    
    with open("team_standings/{}.html".format(year), "w+") as f:
        f.write(data.text)

# %%
dfs = []
for year in years:
    with open("team_standings/{}.html".format(year)) as f:
        page = f.read()
    
    soup = BeautifulSoup(page, 'html.parser')
    soup.find('tr', class_="thead").decompose()
    e_table = soup.find_all(id="divs_standings_E")[0]
    e_df = pd.read_html(str(e_table))[0]
    e_df["Year"] = year
    e_df["Team"] = e_df["Eastern Conference"]
    del e_df["Eastern Conference"]
    dfs.append(e_df)
    
    w_table = soup.find_all(id="divs_standings_W")[0]
    w_df = pd.read_html(str(w_table))[0]
    w_df["Year"] = year
    w_df["Team"] = w_df["Western Conference"]
    del w_df["Western Conference"]
    dfs.append(w_df)

# %%
team_standings = pd.concat(dfs)

# %%
team_standings.to_csv("team_standings.csv")

# %% [markdown]
# **Data cleaning and combining mvp votes player stats and team standings.**

# %%
mvps = pd.read_csv("mvp_votes.csv")
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]
mvps
# Out:
#               Player  Year  Pts Won  Pts Max  Share
# 0     Michael Jordan  1991    891.0      960  0.928
# 1      Magic Johnson  1991    497.0      960  0.518
# 2     David Robinson  1991    476.0      960  0.496
# 3    Charles Barkley  1991    222.0      960  0.231
# 4        Karl Malone  1991    142.0      960  0.148
# ..               ...   ...      ...      ...    ...
# 494    Stephen Curry  2023      5.0     1000  0.005
# 495     Jimmy Butler  2023      3.0     1000  0.003
# 496     De'Aaron Fox  2023      2.0     1000  0.002
# 497    Jalen Brunson  2023      1.0     1000  0.001
# 498        Ja Morant  2023      1.0     1000  0.001
#
# [499 rows x 5 columns]

# %%
players = pd.read_csv("players_stats.csv")
del players["Rk"]
del players["Unnamed: 0"]

# %%
advanced_stats = pd.read_csv("players_advanced_stats.csv")
del advanced_stats["Unnamed: 0"]

# %%
players["Player"] = players["Player"].str.replace("*","",regex=False)
advanced_stats["Player"] = advanced_stats["Player"].str.replace("*","",regex=False)

# %%
def single_row(df):
    if df.shape[0] == 1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row
advanced_stats = advanced_stats.groupby(["Player", "Year"]).apply(single_row)
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
advanced_stats.index = advanced_stats.index.droplevel()
advanced_stats.index = advanced_stats.index.droplevel()

# %%
players.index = players.index.droplevel()
players.index = players.index.droplevel()

# %%
advanced_stats = advanced_stats[['Player','Year','PER', 'TS%',
       '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
       'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']]

# %%
advanced_stats
# Out:
#               Player  Year   PER   TS%  3PAr   FTr  ORB%  DRB%  TRB% AST%  \
# 164       A.C. Green  1991  13.8  .556  .101  .557  11.3  16.2  13.8  4.5
# 633       A.C. Green  1992  16.7  .556  .070  .569  11.8  18.2  14.9  6.0
# 1092      A.C. Green  1993  16.3  .603  .065  .531  11.5  17.3  14.4  5.9
# 1579      A.C. Green  1994  17.0  .555  .038  .391  11.1  18.8  15.0  6.9
# 2067      A.C. Green  1995  14.2  .596  .206  .556   8.3  20.4  14.3  6.5
# ...              ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 6095  Željko Rebrača  2002  16.2  .569  .000  .468   8.4  20.5  14.5  5.7
# 6595  Željko Rebrača  2003  14.0  .596  .000  .331   6.5  16.0  11.2  3.6
# 7176  Željko Rebrača  2004  10.5  .504  .000  .390   9.9  14.6  12.2  4.0
# 7776  Željko Rebrača  2005  14.0  .625  .000  .363   6.5  16.9  11.9  4.8
# 8370  Željko Rebrača  2006  10.7  .592  .000  .427   3.8  13.8   9.0  3.5
#
#       ...  TOV%  USG%  OWS  DWS   WS WS/48  OBPM  DBPM   BPM  VORP
# ...

# %%
players = players.merge(advanced_stats, how="outer", on=["Player", "Year"])
players
# Out:
#                Player  Pos  Age   Tm    G   GS    MP   FG   FGA   FG%  ...  \
# 0          A.C. Green   PF   27  LAL   82   21  26.4  3.1   6.6  .476  ...
# 1          A.C. Green   PF   28  LAL   82   53  35.4  4.7   9.8  .476  ...
# 2          A.C. Green   PF   29  LAL   82   55  34.4  4.6   8.6  .537  ...
# 3          A.C. Green   PF   30  PHO   82   55  34.5  5.7  11.3  .502  ...
# 4          A.C. Green   SF   31  PHO   82   52  32.8  3.8   7.5  .504  ...
# ...               ...  ...  ...  ...  ...  ...   ...  ...   ...   ...  ...
# 15233  Željko Rebrača    C   31  ATL   24    2  11.4  1.4   3.2  .442  ...
# 15234  Željko Rebrača    C   32  LAC   58    2  16.0  2.3   4.0  .568  ...
# 15235  Željko Rebrača    C   33  LAC   29    2  14.2  1.8   3.3  .542  ...
# 15236  Alperen Sengun  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
# 15237  Alperen Sengun  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN   NaN  ...
#
#        TOV%  USG%  OWS  DWS   WS WS/48  OBPM  DBPM   BPM  VORP
# ...

# %%
players.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP'],
#       dtype='object')

# %%
combined = players.merge(mvps, how="outer", on=["Player", "Year"])
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year', 'PER',
#        'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%',
#        'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'Pts Won', 'Pts Max', 'Share'],
#       dtype='object')

# %%
teams = pd.read_csv("team_standings.csv")
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
nicknames = {}

with open("nicknames.txt") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev, name = line.replace("\n", "").split(",")
        nicknames[abbrev] = name

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
stats = combined.merge(teams, how = "outer", on = ["Team", "Year"])

# %%
del stats["Unnamed: 0"]

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player     object
# Pos        object
# Age       float64
# Tm         object
# G         float64
#            ...
# W/L%      float64
# GB         object
# PS/G      float64
# PA/G      float64
# SRS       float64
# Length: 61, dtype: object

# %%
stats["GB"].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '13.0', '25.0',
#        '8.0', '19.0', '3.0', '1.0', '17.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '31.0', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5', nan],
#       dtype=object)

# %%
stats["GB"] = stats["GB"].str.replace("—","0")

# %%
stats["GB"] = pd.to_numeric(stats["GB"])
stats.dtypes
# Out:
# Player     object
# Pos        object
# Age       float64
# Tm         object
# G         float64
#            ...
# W/L%      float64
# GB        float64
# PS/G      float64
# PA/G      float64
# SRS       float64
# Length: 61, dtype: object

# %%
stats.to_csv("player_mvp_stats.csv")
